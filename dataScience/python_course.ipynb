# %%
import os
os.chdir("C:/Users/rish-hp/Desktop/New folder/python_detect_eye_haarcascade/dataScience")

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pollution_data=pd.read_csv("UFOPOLLUTANTS.csv")
pollution_data=pollution_data.head(1000)

# %%
pollution_data.head()
# Out:
#    State.Code                         city state  day  month  year  hour  \
# 0           4  kingman (desert&#44 out of)    az    7      7  2000    21
# 1           4               tacna (approx)    az    7      7  2000    21
# 2           4              apache junction    az    6      9  2001    21
# 3           4                       sedona    az    5      6  2005    21
# 4           4                       tucson    az    5     10  2007     2
#
#    NO2.Mean  NO2.1st.Max.Value  NO2.1st.Max.Hour  ...  O3.AQI  SO2.Mean  \
# 0  7.375000               15.0                 6  ...      45    1.0000
# 1  7.375000               15.0                 6  ...      45    1.0000
# 2  7.708333               19.0                 6  ...      31    0.1875
# 3  7.916667               17.0                 6  ...      41    3.0000
# 4  8.625000               20.0                 6  ...      34    0.0375
#
#    SO2.1st.Max.Value  SO2.1st.Max.Hour  SO2.AQI   CO.Mean  CO.1st.Max.Value  \
# ...

# %%
sns.displot(pollution_data["NO2.AQI"])
plt.show()

# %%
dist =sns.distplot(pollution_data["NO2.AQI"],color="green")
dist.set_title("air pollution")
dist.set_xlabel("index of NO2")
plt.show()

# %%
dist =sns.distplot(pollution_data["NO2.AQI"],color="green",vertical=True)
dist.set_title("air pollution")
dist.set_xlabel("index of NO2")
plt.show()

# %%
dist =sns.distplot(pollution_data["NO2.AQI"],color="green",kde=False)
dist.set_title("air pollution")
dist.set_xlabel("index of NO2")
dist.set_ylabel("frequency")
plt.show()

# %%
dist =sns.distplot(pollution_data["NO2.AQI"],color="green", bins=140)
dist.set_title("air pollution")
dist.set_xlabel("index of NO2")
plt.show()

# %%
dist =sns.distplot(pollution_data["NO2.AQI"],color="green",hist=False)
dist.set_title("air pollution")
dist.set_xlabel("index of NO2")
plt.show()

# %%
rug=sns.rugplot(pollution_data["NO2.AQI"],height=0.7,axis="x")
rug.set_title("rug plat")
rug.set_xlabel("AQI of NO2")
plt.show()

# %%
plt.subplots(figsize=(20,5))
dist=sns.distplot(pollution_data["NO2.AQI"],bins=95, rug=True)
dist.set_title("histogram, KED and rug plot")
dist.set_xlabel("AQI of NO2")
plt.show()

# %%
sns.set(color_codes=True)
plot=sns.kdeplot(pollution_data["NO2.AQI"],shade=True, color='b')

# %%
data=pollution_data
print(data)

# %%
sns.pairplot(pollution_data, height=5, vars=["NO2.Mean","CO.Mean"])
plt.show()

# %%
sns.pairplot(pollution_data, height=5, vars=["NO2.Mean","CO.Mean"],hue="year")
plt.show()

# %%
pollution_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   State.Code         1000 non-null   int64
#  1   city               1000 non-null   object
#  2   state              1000 non-null   object
#  3   day                1000 non-null   int64
#  4   month              1000 non-null   int64
#  5   year               1000 non-null   int64
#  6   hour               1000 non-null   int64
#  7   NO2.Mean           1000 non-null   float64
#  8   NO2.1st.Max.Value  1000 non-null   float64
#  9   NO2.1st.Max.Hour   1000 non-null   int64
#  10  NO2.AQI            1000 non-null   int64
#  11  O3.Mean            1000 non-null   float64
#  12  O3.1st.Max.Value   1000 non-null   float64
#  13  O3.1st.Max.Hour    1000 non-null   int64
#  14  O3.AQI             1000 non-null   int64
#  15  SO2.Mean           1000 non-null   float64
# ...

# %%
sns.lmplot(x= "NO2.1st.Max.Value",y="SO2.1st.Max.Value",data=pollution_data )
plt.show()

# %%
sns.lmplot(x= "NO2.1st.Max.Value",y="SO2.1st.Max.Value",data=pollution_data,x_jitter=2.5,y_jitter=2.5 )
plt.show()
